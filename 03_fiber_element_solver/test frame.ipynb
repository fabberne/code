# %%
import sys
import os

# Add the src folder to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), 'src')))

import numpy as np
import matplotlib.pyplot as plt

from mesh import *
from geometry import *
import material
import cross_section
import beam_element
import structure
import solver

# %%
HEA_200 = H_beam(web_width     =   6.5,
                 web_height    = 170.0,
                 flange_width  = 200.0,
                 flange_height =  10.0)
beam = Mesh(HEA_200, mesh_type="triangle", mesh_size=20)
beam.plot()

HEB_300 = H_beam(web_width     =  11.0,
                 web_height    = 262.0,
                 flange_width  = 300.0,
                 flange_height =  19.0)
column = Mesh(HEB_300, mesh_type="triangle", mesh_size=20)
column.plot()

# %%
struc = structure.Frame(column            = column, 
						beam              = beam, 
						number_of_stories = 3, 
						story_height      = 3000, 
						story_width       = 7000, 
						number_of_sections_per_elemnt = 3)

# %%
lin_solver = solver.Linear(struc)

lin_solver.plot_initial_structure()

# %%
load_DOFs   = [6 * 6   , 6 * 6 + 1, 6 * 7 + 1]
nodal_loads = [100000.0,    5000.0,   -5000.0]

lin_solver.solve(load_DOFs, nodal_loads)
lin_solver.plot_displaced_structure(scale=20.0)
# Out:
# --------------------------------------
# Node 0
#           Displacement
# u [mm]        0.000000
# v [mm]        0.000000
# w [mm]        0.000000
# θx [rad]      0.000000
# θy [rad]      0.000000
# θz [rad]      0.000000
#           Internal Force
# Fx [kN]       -50.135328
# Fy [kN]        -5.000000
# Fz [kN]       -62.659625
# Mx [kNm]       45.000000
# My [kNm]     -230.801037
# Mz [kNm]        0.000000
# --------------------------------------
# Node 1
#           Displacement
# u [mm]        0.000000
# v [mm]        0.000000
# w [mm]        0.000000
# θx [rad]      0.000000
# θy [rad]      0.000000
# θz [rad]      0.000000
#           Internal Force
# Fx [kN]       -49.864672
# Fy [kN]         5.000000
# Fz [kN]        62.659625
# Mx [kNm]      -45.000000
# My [kNm]     -230.581591
# Mz [kNm]        0.000000
# --------------------------------------
# Node 2
#           Displacement
# u [mm]       16.012580
# v [mm]       10.039563
# w [mm]        0.062676
# θx [rad]     -0.006275
# θy [rad]      0.009194
# θz [rad]     -0.002866
#           Internal Force
# Fx [kN]        -0.000000
# Fy [kN]         0.000000
# Fz [kN]        -0.000000
# Mx [kNm]        0.000000
# My [kNm]        0.000000
# Mz [kNm]       -0.000000
# --------------------------------------
# Node 3
#           Displacement
# u [mm]       16.017119
# v [mm]      -10.039563
# w [mm]       -0.062676
# θx [rad]      0.006275
# θy [rad]      0.009205
# θz [rad]     -0.002866
#           Internal Force
# Fx [kN]        -0.000000
# Fy [kN]         0.000000
# Fz [kN]        -0.000000
# Mx [kNm]        0.000000
# My [kNm]        0.000000
# Mz [kNm]       -0.000000
# --------------------------------------
# Node 4
#           Displacement
# u [mm]       51.472447
# v [mm]       35.138472
# w [mm]        0.108792
# θx [rad]     -0.010040
# θy [rad]      0.012985
# θz [rad]     -0.010036
#           Internal Force
# Fx [kN]        -0.000000
# Fy [kN]        -0.000000
# Fz [kN]        -0.000000
# Mx [kNm]        0.000000
# My [kNm]       -0.000000
# Mz [kNm]        0.000000
# --------------------------------------
# Node 5
#           Displacement
# u [mm]       51.465395
# v [mm]      -35.138472
# w [mm]       -0.108792
# θx [rad]      0.010040
# θy [rad]      0.012934
# θz [rad]     -0.010036
#           Internal Force
# Fx [kN]         0.000000
# Fy [kN]        -0.000000
# Fz [kN]        -0.000000
# Mx [kNm]        0.000000
# My [kNm]       -0.000000
# Mz [kNm]        0.000000
# --------------------------------------
# Node 6
#           Displacement
# u [mm]       92.301766
# v [mm]       67.767053
# w [mm]        0.131590
# θx [rad]     -0.011295
# θy [rad]      0.012742
# θz [rad]     -0.019358
#           Internal Force
# Fx [kN]       200.000000
# Fy [kN]        10.000000
# Fz [kN]         0.000000
# Mx [kNm]       -0.000000
# My [kNm]        0.000000
# Mz [kNm]       -0.000000
# --------------------------------------
# Node 7
#           Displacement
# u [mm]       91.978686
# v [mm]      -67.767053
# w [mm]       -0.131590
# θx [rad]      0.011295
# θy [rad]      0.012613
# θz [rad]     -0.019358
#           Internal Force
# Fx [kN]        -0.000000
# Fy [kN]       -10.000000
# Fz [kN]        -0.000000
# Mx [kNm]        0.000000
# My [kNm]        0.000000
# Mz [kNm]        0.000000
