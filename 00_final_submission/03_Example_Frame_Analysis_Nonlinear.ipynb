# %% [markdown]
# # 03 Example: Nonlinear Frame Analysis
# ___

# %% [markdown]
# ## Setup
# import all the needed libraries and files.

# %%
import numpy as np

from Structure import *
from Material import *
from Solver import *

from Plotting_Functions import *

# %% [markdown]
# ## Generate the Geometry and the corresponding mesh

# %%
# Initalize the geometry of the column
HEB_300 = H_beam(web_width     =  11.0,
                 web_height    = 262.0,
                 flange_width  = 300.0,
                 flange_height =  19.0)

# Create the mesh of the column
column = Mesh(HEB_300, mesh_type="quadrilateral", mesh_size=20)

# Print and plot the mesh of the column
column.plot()
column.print()
# Out:
# ╒════════════════════╤═══════════════╕
# │ Mesh Type          │ quadrilateral │
# ├────────────────────┼───────────────┤
# │ Number of elements │ 43            │
# ├────────────────────┼───────────────┤
# │ Number of nodes    │ 88            │
# ├────────────────────┼───────────────┤
# │ Cross Section Area │ 14282.00      │
# ╘════════════════════╧═══════════════╛
# ╒══════════════════════════╤══════════╤══════════╕
# │                          │ y        │ z        │
# ╞══════════════════════════╪══════════╪══════════╡
# │ Centroid [mm]            │ 0.00     │ 0.00     │
# ├──────────────────────────┼──────────┼──────────┤
# │ Moment of inertia [mm^4] │ 2.42e+08 │ 8.55e+07 │
# ╘══════════════════════════╧══════════╧══════════╛

# %% [markdown]
# ## Structure
# Initialize the structure. For a frame, one has to define the columns and the beams geometry, the number of storeys, their width and height as well as the DOF where nodal loads will be applied and their value.
#
# Each node has 6 DOFs (counting starts from 0). The nodes start counting on the bottom left (0), then bottom right (1), then one storey up on the left side (2) and so on. To apply a lateral load we need the first DOF (global x-direction) of the node number 2, so therefore DOF n*6 = 2*6 = 12.

# %%
frame = Frame(column            = column, 
			  beam              = column, 
			  number_of_stories = 1, 
			  story_height      = 3000, 
			  story_width       = 7000,
			  load_DOFs         = [12],
			  nodal_loads       = [1],
			  number_of_sections_per_elemnt = 10)

plot_initial_structure(frame)

# %% [markdown]
# ## Solver

# %%
non_linear_solver = Nonlinear(frame, constraint="Load")

# %%
increments = np.zeros(140)
increments.fill(5000)

u_history, lambda_history, section_forces, section_strains = non_linear_solver.solve(increments)
# Out:
#   0%|          | 0/140 [00:00<?, ?it/s]
# ----------------------------------------------
# Load step 1 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.3428007491026083e-09
# NR Converged!
# ----------------------------------------------
# Load step 2 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8062904113499834e-09
# NR Converged!
# ----------------------------------------------
# Load step 3 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.8812088862791056e-09
# NR Converged!
# ----------------------------------------------
# Load step 4 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.8793928994965995e-09
# NR Converged!
# ----------------------------------------------
# Load step 5 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.734817623601267e-09
# NR Converged!
# ----------------------------------------------
# Load step 6 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.881786077987847e-09
# NR Converged!
# ----------------------------------------------
# Load step 7 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.734925675705651e-09
# NR Converged!
# ----------------------------------------------
# Load step 8 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.734096393321752e-09
# NR Converged!
# ----------------------------------------------
# Load step 9 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.274727179416134e-09
# NR Converged!
# ----------------------------------------------
# Load step 10 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.651313554360722e-10
# NR Converged!
# ----------------------------------------------
# Load step 11 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.734925675705651e-09
# NR Converged!
# ----------------------------------------------
# Load step 12 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.733651552740092e-09
# NR Converged!
# ----------------------------------------------
# Load step 13 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7.454808236991889e-09
# NR Converged!
# ----------------------------------------------
# Load step 14 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7.4552724764215e-09
# NR Converged!
# ----------------------------------------------
# Load step 15 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.053979298376401e-08
# NR Converged!
# ----------------------------------------------
# Load step 16 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7.45524584779026e-09
# NR Converged!
# ----------------------------------------------
# Load step 17 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7.454963578451423e-09
# NR Converged!
# ----------------------------------------------
# Load step 18 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.6097902528290716e-10
# NR Converged!
# ----------------------------------------------
# Load step 19 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.5482087450876677e-10
# NR Converged!
# ----------------------------------------------
# Load step 20 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7.45524584779026e-09
# NR Converged!
# ----------------------------------------------
# Load step 21 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.0539738988232972e-08
# NR Converged!
# ----------------------------------------------
# Load step 22 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.497519482034098e-10
# NR Converged!
# ----------------------------------------------
# Load step 23 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7.45571338834833e-09
# NR Converged!
# ----------------------------------------------
# Load step 24 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.5719249449515535e-10
# NR Converged!
# ----------------------------------------------
# Load step 25 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.5257111640108317e-10
# NR Converged!
# ----------------------------------------------
# Load step 26 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.4903227397690562e-08
# NR Converged!
# ----------------------------------------------
# Load step 27 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.470613522214938e-10
# NR Converged!
# ----------------------------------------------
# Load step 28 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7658210905426257e-10
# NR Converged!
# ----------------------------------------------
# Load step 29 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.2803482634793646e-10
# NR Converged!
# ----------------------------------------------
# Load step 30 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.490383437111512e-08
# NR Converged!
# ----------------------------------------------
# Load step 31 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.510205376893282e-10
# NR Converged!
# ----------------------------------------------
# Load step 32 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.490340855986688e-08
# NR Converged!
# ----------------------------------------------
# Load step 33 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.808792945427939e-10
# NR Converged!
# ----------------------------------------------
# Load step 34 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.780615511295235e-10
# NR Converged!
# ----------------------------------------------
# Load step 35 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.3489626557213963e-10
# NR Converged!
# ----------------------------------------------
# Load step 36 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7158431629998143e-10
# NR Converged!
# ----------------------------------------------
# Load step 37 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8226589698563947e-10
# NR Converged!
# ----------------------------------------------
# Load step 38 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.297405939876181e-10
# NR Converged!
# ----------------------------------------------
# Load step 39 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.490380861853855e-08
# NR Converged!
# ----------------------------------------------
# Load step 40 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.808792945427939e-10
# NR Converged!
# ----------------------------------------------
# Load step 41 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.780615511295235e-10
# NR Converged!
# ----------------------------------------------
# Load step 42 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.3489626557213963e-10
# NR Converged!
# ----------------------------------------------
# Load step 43 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.688168490117993e-10
# NR Converged!
# ----------------------------------------------
# Load step 44 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8525094652886996e-10
# NR Converged!
# ----------------------------------------------
# Load step 45 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.2985578105626794e-10
# NR Converged!
# ----------------------------------------------
# Load step 46 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.4903676302874512e-08
# NR Converged!
# ----------------------------------------------
# Load step 47 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.657468193174234e-10
# NR Converged!
# ----------------------------------------------
# Load step 48 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.490373668869241e-08
# NR Converged!
# ----------------------------------------------
# Load step 49 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.4903727808440417e-08
# NR Converged!
# ----------------------------------------------
# Load step 50 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.4951336962814454e-10
# NR Converged!
# ----------------------------------------------
# Load step 51 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.5878280930597594e-10
# NR Converged!
# ----------------------------------------------
# Load step 52 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980339262347435e-08
# NR Converged!
# ----------------------------------------------
# Load step 53 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.71559949127863e-10
# NR Converged!
# ----------------------------------------------
# Load step 54 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980365906624095e-08
# NR Converged!
# ----------------------------------------------
# Load step 55 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.3655256092037394e-10
# NR Converged!
# ----------------------------------------------
# Load step 56 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.688168490117993e-10
# NR Converged!
# ----------------------------------------------
# Load step 57 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980365906624095e-08
# NR Converged!
# ----------------------------------------------
# Load step 58 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8226589698563947e-10
# NR Converged!
# ----------------------------------------------
# Load step 59 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.3666443255628973e-10
# NR Converged!
# ----------------------------------------------
# Load step 60 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.796278400721441e-10
# NR Converged!
# ----------------------------------------------
# Load step 61 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7165740470219274e-10
# NR Converged!
# ----------------------------------------------
# Load step 62 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980365906624095e-08
# NR Converged!
# ----------------------------------------------
# Load step 63 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.796278400721441e-10
# NR Converged!
# ----------------------------------------------
# Load step 64 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.332849477807962e-10
# NR Converged!
# ----------------------------------------------
# Load step 65 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8226589698563947e-10
# NR Converged!
# ----------------------------------------------
# Load step 66 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7953316329947186e-10
# NR Converged!
# ----------------------------------------------
# Load step 67 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.823596574589065e-10
# NR Converged!
# ----------------------------------------------
# Load step 68 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7165740470219274e-10
# NR Converged!
# ----------------------------------------------
# Load step 69 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980323630927597e-08
# NR Converged!
# ----------------------------------------------
# Load step 70 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8226589698563947e-10
# NR Converged!
# ----------------------------------------------
# Load step 71 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.823596574589065e-10
# NR Converged!
# ----------------------------------------------
# Load step 72 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7953316329947186e-10
# NR Converged!
# ----------------------------------------------
# Load step 73 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7953316329947186e-10
# NR Converged!
# ----------------------------------------------
# Load step 74 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.332849477807962e-10
# NR Converged!
# ----------------------------------------------
# Load step 75 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8226589698563947e-10
# NR Converged!
# ----------------------------------------------
# Load step 76 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.7953316329947186e-10
# NR Converged!
# ----------------------------------------------
# Load step 77 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.823596574589065e-10
# NR Converged!
# ----------------------------------------------
# Load step 78 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.823596574589065e-10
# NR Converged!
# ----------------------------------------------
# Load step 79 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.332849477807962e-10
# NR Converged!
# ----------------------------------------------
# Load step 80 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8226589698563947e-10
# NR Converged!
# ----------------------------------------------
# Load step 81 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.6871836326055036e-10
# NR Converged!
# ----------------------------------------------
# Load step 82 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  141348.16787998064
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.6269535826722567e-11
# NR Converged!
# ----------------------------------------------
# Load step 83 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7.165987191398827e-11
# NR Converged!
# ----------------------------------------------
# Load step 84 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  252183.31294948625
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.637978807849591e-11
# NR Converged!
# ----------------------------------------------
# Load step 85 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  38250.39741558247
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.605013341686718e-18
# NR Converged!
# ----------------------------------------------
# Load step 86 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  521673.34327423334
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980234015125842e-08
# NR Converged!
# ----------------------------------------------
# Load step 87 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  454638.1796906925
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.2539071653444894e-11
# NR Converged!
# ----------------------------------------------
# Load step 88 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  355281.8086407583
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980239699458918e-08
# NR Converged!
# ----------------------------------------------
# Load step 89 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  239315.98400005948
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  6.173854762339534e-11
# NR Converged!
# ----------------------------------------------
# Load step 90 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#       Residuals Norm  234411.44371444563
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.56447670897592e-11
# NR Converged!
# ----------------------------------------------
# Load step 91 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  230683.24465362297
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980239699458918e-08
# NR Converged!
# ----------------------------------------------
# Load step 92 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  10642.083981025153
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.2539071653442684e-11
# NR Converged!
# ----------------------------------------------
# Load step 93 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  50214.92504216926
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.980239699458918e-08
# NR Converged!
# ----------------------------------------------
# Load step 94 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#       Residuals Norm  239604.44494868658
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  9076.26574587086
#       NR Iteration  2
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.98023969945895e-08
# NR Converged!
# ----------------------------------------------
# Load step 95 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  25873.269049733448
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.999908354159456e-11
# NR Converged!
# ----------------------------------------------
# Load step 96 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  27223.071873456603
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960465188081756e-08
# NR Converged!
# ----------------------------------------------
# Load step 97 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  58427.05200487639
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  8.429370455823153e-08
# NR Converged!
# ----------------------------------------------
# Load step 98 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  19338.135180993428
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.910383045673494e-11
# NR Converged!
# ----------------------------------------------
# Load step 99 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  35077.197317256534
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.253907165344343e-11
# NR Converged!
# ----------------------------------------------
# Load step 100 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  35684.160611355124
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.4551915228402324e-11
# NR Converged!
# ----------------------------------------------
# Load step 101 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  48197.076216369955
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960476734388652e-08
# NR Converged!
# ----------------------------------------------
# Load step 102 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  48349.653778587424
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  8.429370330215766e-08
# NR Converged!
# ----------------------------------------------
# Load step 103 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.8848047952636206e-10
# NR Converged!
# ----------------------------------------------
# Load step 104 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5756.040719030806
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960465188081756e-08
# NR Converged!
# ----------------------------------------------
# Load step 105 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  15464.178142855942
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.2539071653445954e-11
# NR Converged!
# ----------------------------------------------
# Load step 106 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  7413.169635126249
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960478688376837e-08
# NR Converged!
# ----------------------------------------------
# Load step 107 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  19037.433068452076
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960467497344925e-08
# NR Converged!
# ----------------------------------------------
# Load step 108 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960467497344925e-08
# NR Converged!
# ----------------------------------------------
# Load step 109 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960468207887258e-08
# NR Converged!
# ----------------------------------------------
# Load step 110 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.2433161821273363e-10
# NR Converged!
# ----------------------------------------------
# Load step 111 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  410256.8365768234
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.455191522838079e-11
# NR Converged!
# ----------------------------------------------
# Load step 112 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  35030.427752316515
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960467497344925e-08
# NR Converged!
# ----------------------------------------------
# Load step 113 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  172185.1690475376
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  4603.033593045095
#       NR Iteration  2
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.0579515874459994e-11
# NR Converged!
# ----------------------------------------------
# Load step 114 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  216658.1584354673
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.820766091348059e-11
# NR Converged!
# ----------------------------------------------
# Load step 115 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  484449.52896060643
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  8.429370330215766e-08
# NR Converged!
# ----------------------------------------------
# Load step 116 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
# ...
#       Residuals Norm  1.1999816708318152e-10
# NR Converged!
# ----------------------------------------------
# Load step 119 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  664062.1008571569
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960465365717416e-08
# NR Converged!
# ----------------------------------------------
# Load step 120 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  656832.9133740044
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960490234657581e-08
# NR Converged!
# ----------------------------------------------
# Load step 121 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#       Residuals Norm  454533.3449417769
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  22715.488137429253
#       NR Iteration  2
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960467674980516e-08
# NR Converged!
# ----------------------------------------------
# Load step 122 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  440657.38000852754
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960476023847335e-08
# NR Converged!
# ----------------------------------------------
# Load step 123 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  212997.5052415985
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.999908354159133e-11
# NR Converged!
# ----------------------------------------------
# Load step 124 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  120409.38450091217
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  3.700328803804503e-17
# NR Converged!
# ----------------------------------------------
# Load step 125 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  550648.0052975517
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  134659.33538978506
#       NR Iteration  2
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.999908419720366e-11
# NR Converged!
# ----------------------------------------------
# Load step 126 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  639168.6441403613
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  8.42937095825269e-08
# NR Converged!
# ----------------------------------------------
# Load step 127 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  100030.94121949334
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.473825588822403e-10
# NR Converged!
# ----------------------------------------------
# Load step 128 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  293981.7607223653
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1910.9368803414782
#       NR Iteration  2
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.820766091347711e-11
# NR Converged!
# ----------------------------------------------
# Load step 129 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  280742.703644843
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.1822031817627756e-10
# NR Converged!
# ----------------------------------------------
# Load step 130 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  90978.57547018648
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960467319709328e-08
# NR Converged!
# ----------------------------------------------
# Load step 131 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  178337.08690348902
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.213094437217855e-16
# NR Converged!
# ----------------------------------------------
# Load step 132 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  290624.66080924915
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.2347709524676055e-10
# NR Converged!
# ----------------------------------------------
# Load step 133 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  12348.28962157048
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960465188081756e-08
# NR Converged!
# ----------------------------------------------
# Load step 134 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  76221.76527460598
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#             Element iteration  1
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  10969.411482097988
#       NR Iteration  2
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  4.4274052810723726e-17
# NR Converged!
# ----------------------------------------------
# Load step 135 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#             Element iteration  2
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  154488.02442405352
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960468030251766e-08
# NR Converged!
# ----------------------------------------------
# Load step 136 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  150672.51835612213
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  8.429372716755788e-08
# NR Converged!
# ----------------------------------------------
# Load step 137 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  49225.97774558949
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  123.80901442270009
#       NR Iteration  2
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  1.1641532182693554e-10
# NR Converged!
# ----------------------------------------------
# Load step 138 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  27268.163054629073
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  2.910383045722476e-11
# NR Converged!
# ----------------------------------------------
# Load step 139 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  14481.628713039892
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.960468030251683e-08
# NR Converged!
# ----------------------------------------------
# Load step 140 of 140
#    Attempt  1
#       NR Iteration  0
#          Beam Element  1
#             Element iteration  0
#             Element iteration  1
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#             Element iteration  1
#       Residuals Norm  41004.4817883947
#       NR Iteration  1
#          Beam Element  1
#             Element iteration  0
#          Beam Element  2
#             Element iteration  0
#          Beam Element  3
#             Element iteration  0
#       Residuals Norm  5.820766091445162e-11
# NR Converged!

# %% [markdown]
# ## Load Displacement Curve

# %%
import matplotlib.pyplot as plt

# Main figure and axes
fig, ax = plt.subplots(figsize=(4, 3))
plt.rcParams["font.family"] = "Times New Roman"


ax.plot(u_history[:,12], lambda_history/1000,   label="Frame", color='k')
ax.scatter(u_history[:,12][80], lambda_history[80]/1000, color='C0', s=30, zorder=5, marker='s')
ax.scatter(u_history[:,12][105], lambda_history[105]/1000, color='C1', s=30, zorder=5, marker='s')
ax.scatter(u_history[:,12][130], lambda_history[130]/1000, color='C2', s=30, zorder=5, marker='s')
ax.set_xlabel("Displacement $u$ [$mm$]")
ax.set_ylabel("Load Factor $\\lambda$ [$kN$]")
ax.grid()
plt.show()

# %% [markdown]
# ## Section Forces and Curvature

# %%
steps = [80, 105, 130]
plot_moments(steps, section_forces, section_strains, non_linear_solver, length=3000)

# %% [markdown]
# ## Cross Section Analysis
# ___

# %% [markdown]
# ### Setup Analysis

# %%
Analysis = stress_strain_analysis(column)

# %% [markdown]
# ### Apply some given strains

# %%
Analysis.set_strain_and_curvature(0.00, 0.00001, 0.000005)

Analysis.calculate_strains()
Analysis.calculate_stresses()

print(Analysis.get_section_forces())

plot_stress_strain_steel(Analysis)
# Out:
# (1.0186340659856796e-13, 387.16040282274594, 20.90070616793812)

# %%
strains = np.linspace(-0.004, 0.004, 500)
plot_linear_variation_eps(Analysis, strains)

# %%
curvs = np.linspace(-0.00004, 0.00004, 100)
plot_linear_variation_curv(Analysis, curvs)

# %% [markdown]
# ### $N-M$ and $M_y-M_z$ influence plots

# %%
N = [0, 1000, 1500, 2000, 2500]
My_lim = [-450, 450]
Mz_lim = [-220, 220]
plot_influence_of_N_on_M(Analysis, N, My_lim, Mz_lim)

# %%
Mz = [0, 50, 100, 150]
My_lim = [-450, 450]
plot_influence_of_Mz_on_My(Analysis, My_lim, Mz)
